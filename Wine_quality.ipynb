# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression 
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
wine = pd.read_csv(r'C:\Users\User\Desktop\Gamboo (1)\Wine quality\Wine.csv')

# %%
wine.head()
# Out:
#    fixed acid  volatile acid  citric acid  residual sugar  chlorid  \
# 0         7.4           0.70         0.00             1.9    0.076
# 1         7.8           0.88         0.00             2.6    0.098
# 2         7.8           0.76         0.04             2.3    0.092
# 3        11.2           0.28         0.56             1.9    0.075
# 4         7.4           0.70         0.00             1.9    0.076
#
#    free sulfur dioxide  sum of sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                   34.0   0.9978  3.51       0.56
# 1                 25.0                   67.0   0.9968  3.20       0.68
# 2                 15.0                   54.0   0.9970  3.26       0.65
# 3                 17.0                   60.0   0.9980  3.16       0.58
# 4                 11.0                   34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# ...

# %%
wine.isna().sum()
# Out:
# fixed acid               0
# volatile acid            0
# citric acid              0
# residual sugar           0
# chlorid                  0
# free sulfur dioxide      0
# sum of sulfur dioxide    0
# density                  0
# pH                       0
# sulphates                0
# alcohol                  0
# quality                  0
# Id                       0
# dtype: int64

# %%
columns = wine.columns[:12]

# %%
columns
# Out:
# Index(['fixed acid', 'volatile acid', 'citric acid', 'residual sugar',
#        'chlorid', 'free sulfur dioxide', 'sum of sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.pairplot(data = wine , hue = 'quality')

# %%
plt.figure(figsize = (10 , 7))
sns.scatterplot(wine['pH'] , wine['free sulfur dioxide'] , hue= wine['quality'] , s = wine['quality'] * 11 )
plt.show()
plt.savefig('Wine_vis')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(wine['quality'])
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
columns2 = wine.columns[:11]

# %%
for x in columns2:
    sns.catplot('quality' , x  , data = wine)
    plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize = (12 , 7))
sns.heatmap(wine[columns].corr() , annot= True)
# Out:
# <AxesSubplot:>

# %%
x = wine[columns2]
y = wine.quality

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y  , test_size= 0.2)

# %% [markdown]
# # DecisionTreeClassifier

# %%
dec = DecisionTreeClassifier(random_state= 100 , min_samples_leaf= 5 , max_depth= 5)

# %%
dec.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=5, random_state=100)

# %%
dec_pred = dec.predict(x_test)

# %%
accuracy_score(y_test , dec_pred)
# Out:
# 0.5502183406113537

# %% [markdown]
# # LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(x_train , y_train)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_pred = log.predict(x_test)

# %%
accuracy_score(y_test , log_pred)
# Out:
# 0.6069868995633187

# %% [markdown]
# # RandomForestClassifier

# %%
ran = RandomForestClassifier(n_estimators= 120)

# %%
ran.fit(x_train , y_train)
# Out:
# RandomForestClassifier(n_estimators=120)

# %%
ran_pred = ran.predict(x_test)

# %%
accuracy_score(y_test , ran_pred)
# Out:
# 0.6855895196506551

# %% [markdown]
# # SVC

# %%
sv = SVC()

# %%
sv.fit(x_train , y_train)
# Out:
# SVC()

# %%
sv_pred = sv.predict(x_test)

# %%
accuracy_score(y_test , sv_pred)
# Out:
# 0.5065502183406113

# %% [markdown]
# # KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors= 5 , metric = 'euclidean')

# %%
knn.fit(x_train , y_train)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
knn_pred = knn.predict(x_test)

# %%
accuracy_score(y_test , knn_pred)
# Out:
# 0.5152838427947598

# %% [markdown]
# # ExtraTreesClassifier

# %%
ex_tree = ExtraTreesClassifier()

# %%
ex_tree.fit(x_train , y_train)
# Out:
# ExtraTreesClassifier()

# %%
ex_tree_pred = ex_tree.predict(x_test)

# %%
accuracy_score(y_test , ex_tree_pred)
# Out:
# 0.6812227074235808

# %%
ex_pred2 = ex_tree.predict(x)

# %%
pred_data = x

# %%
pred_data['Predict_quality'] = ex_pred2
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_10452/1767102052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pred_data['Predict_quality'] = ex_pred2

# %%
pred_data
# Out:
#       fixed acid  volatile acid  citric acid  residual sugar  chlorid  \
# 0            7.4          0.700         0.00             1.9    0.076
# 1            7.8          0.880         0.00             2.6    0.098
# 2            7.8          0.760         0.04             2.3    0.092
# 3           11.2          0.280         0.56             1.9    0.075
# 4            7.4          0.700         0.00             1.9    0.076
# ...          ...            ...          ...             ...      ...
# 1138         6.3          0.510         0.13             2.3    0.076
# 1139         6.8          0.620         0.08             1.9    0.068
# 1140         6.2          0.600         0.08             2.0    0.090
# 1141         5.9          0.550         0.10             2.2    0.062
# 1142         5.9          0.645         0.12             2.0    0.075
#
#       free sulfur dioxide  sum of sulfur dioxide  density    pH  sulphates  \
# ...
